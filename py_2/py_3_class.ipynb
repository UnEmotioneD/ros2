# %% [markdown]
# # Class

# %% [markdown]
# ## Function
#
# - Define functions in separate .py file

# %%
import tools

animals = ["tiger", "cat", "puppy"]

result = tools.add(3, 4)
print(result)

lst_result = tools.print_item(animals)
print(lst_result)

count = tools.count_item(animals)
print(count)

# %% [markdown]
# ## Class
#
# - Blueprints for Object which loads to memory

# %%
from user import User

kim = User("kim", "kim@naver", "1234")
print(f"kim's ID: {kim.member_id}")
lee = User("lee", "lee@naver", "5678")
print(f"lee's ID: {lee.member_id}")

kim.login()
lee.login()

del kim  # free from memory

lee.send_email()
